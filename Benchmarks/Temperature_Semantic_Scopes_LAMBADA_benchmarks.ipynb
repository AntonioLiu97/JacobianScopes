# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3"  
# os.environ["CUDA_VISIBLE_DEVICES"] = "2,3"  
from torch import nn


import numpy as np                                                                  
import torch                                          

                              
from transformers import AutoModelForCausalLM, AutoTokenizer  
from tqdm import tqdm
import matplotlib.pyplot as plt  
import torch.nn.functional as F
import gc
import re
import copy

import sys
sys.path.append('..')
import JCBScope_utils

# Move to GPU with optimal dtype
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = "cpu"

# %%
# Load the tokenizer and model

# model_name = "meta-llama/Llama-3.2-1B"
model_name = "meta-llama/Llama-3.2-3B"
# model_name = "meta-llama/Llama-3.1-8B"
model_name_short = model_name.split("/")[-1]
if device == "cpu":
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)
    model = model.to(device)
else:
    tokenizer = AutoTokenizer.from_pretrained(model_name, device_map="auto")
    model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")
    
embedding_layer = model.get_input_embeddings()
embed_device = embedding_layer.weight.device
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]

# %%
# mode = 'Temperature'
# mode = 'Semantic'
mode = 'gradient_x_input'
# mode = 'IG'

top_k_fraction = 0.05
# top_k_fraction = 0.1
# top_k_fraction = 0.2

# %%
presence_list = [0.2,0.4,0.6,0.8,0.1]

# %%
front_pad = 0
back_pad = 0




front_strip = 0
# random_ablation = True
random_ablation = False
# num_prompts = 1
num_prompts = 300


# Get special tokens if available
bos_token_id = tokenizer.bos_token_id if tokenizer.bos_token_id is not None else tokenizer.cls_token_id
eos_token_id = tokenizer.eos_token_id if tokenizer.eos_token_id is not None else tokenizer.sep_token_id

# %%
if (mode == 'Semantic') or (mode == 'IG'):
    unnormalized_logits = True
else:
    unnormalized_logits = False
    

def change_in_max_log_p_with_ablation(string, top_k_fraction=0.1, verbose=True, random_ablation = False):
    """Optimized: single model load, retain_graph=False, free logits before ablation."""
    input_ids_list = tokenizer(string, add_special_tokens=False)["input_ids"]
    if eos_token_id is not None:
        input_ids_list += [eos_token_id] * back_pad

    input_ids = torch.tensor([input_ids_list], dtype=torch.long).to(embed_device)
    attention_mask = torch.ones_like(input_ids, device=embed_device)
    seq_len = input_ids.size(1)

    decoded_tokens = tokenizer.batch_decode([[tid] for tid in input_ids[0].tolist()], skip_special_tokens=True)

    def get_token_indices_for_substring(tokens, substring):
        full = "".join(tokens)
        exclude_indices = set()
        start = 0
        while True:
            pos = full.find(substring, start)
            if pos == -1:
                break
            end = pos + len(substring)
            cumlen = 0
            for i, t in enumerate(tokens):
                tok_end = cumlen + len(t)
                if tok_end > pos and cumlen < end:
                    exclude_indices.add(i)
                cumlen = tok_end
            start = pos + 1
        return exclude_indices

    grad_idx = [idx for idx in range(front_pad, len(decoded_tokens), 1)][front_strip:]

    tick_label_text = [decoded_tokens[idx] for idx in grad_idx]

    d_model = embedding_layer.embedding_dim
    residual = nn.Parameter(torch.zeros(len(grad_idx), d_model, device=embed_device))
    presence = torch.ones(len(decoded_tokens), 1, device=embed_device)
    # Use global model (no reload - avoids OOM from loading 2x per call)
    model.eval()
    forward_pass = JCBScope_utils.customize_forward_pass(
        model, residual, presence, input_ids, grad_idx, attention_mask
    )
    hidden_norm_as_loss = (mode == 'Temperature')
    loss_position = seq_len - 2

    if verbose:
        print(f"Computing {mode} Scope...")
    n_tokens = len(grad_idx)
    n_top = max(1, int(n_tokens * top_k_fraction))
    if random_ablation:
        with torch.no_grad():
            _, logits_orig = forward_pass(
                loss_position=loss_position,
                hidden_norm_as_loss=hidden_norm_as_loss,
                unnormalized_logits=True,
                tie_input_output_embed=False,
            )
        grad_vals = None
        ablated_indices = np.random.choice(n_tokens, size=min(n_top, n_tokens), replace=False)
    else:
        if mode == "IG":
            grad_list = []
            for alpha in presence_list:
                loss, logits_orig = forward_pass(
                    loss_position=loss_position,
                    hidden_norm_as_loss=hidden_norm_as_loss,
                    unnormalized_logits=True,
                    tie_input_output_embed=False,
                    alpha=alpha,
                )
                g = torch.autograd.grad(loss, residual, retain_graph=False)[0]
                grad_list.append(g.detach().clone())
                del loss
            grads = torch.stack(grad_list).mean(dim=0)
            del grad_list
            with torch.no_grad():
                _, logits_orig = forward_pass(
                    loss_position=loss_position,
                    hidden_norm_as_loss=hidden_norm_as_loss,
                    unnormalized_logits=True,
                    tie_input_output_embed=False,
                    alpha=1.0,
                )
        else:
            loss, logits_orig = forward_pass(
                loss_position=loss_position,
                hidden_norm_as_loss=hidden_norm_as_loss,
                unnormalized_logits=unnormalized_logits,
                tie_input_output_embed=False,
            )
            grads = torch.autograd.grad(loss, residual, retain_graph=False)[0]
        if mode == 'gradient_x_input' or mode == 'IG':
            with torch.no_grad():
                token_embeds = JCBScope_utils.embedding_lookup(input_ids[0, grad_idx], embedding_layer)
            grad_vals = (grads * token_embeds.to(grads.device)).norm(dim=-1).squeeze().cpu().numpy()
        if grad_vals.ndim > 1:
            grad_vals = grad_vals.squeeze()
        ablated_indices = grad_vals.argsort()[::-1][:n_top]
        del grads

    max_idx_orig = logits_orig[loss_position].argmax().item()
    max_log_prob_orig = torch.log_softmax(logits_orig[loss_position], dim=-1)[max_idx_orig].item()
    logits_orig_cpu = logits_orig.detach().cpu()
    del logits_orig
    torch.cuda.empty_cache()
    presence_ablated = presence.clone()
    presence_ablated[[grad_idx[i] for i in ablated_indices], 0] = 0.0
    del forward_pass

    forward_pass_ablated = JCBScope_utils.customize_forward_pass(
        model, residual, presence_ablated, input_ids, grad_idx, attention_mask
    )
    with torch.no_grad():
        _, logits_ablated = forward_pass_ablated(
            loss_position=loss_position,
            hidden_norm_as_loss=hidden_norm_as_loss,
            unnormalized_logits=unnormalized_logits,
            tie_input_output_embed=False,
        )

    max_log_prob_ablated = torch.log_softmax(logits_ablated[loss_position], dim=-1)[max_idx_orig].item()
    delta_log_prob = max_log_prob_ablated - max_log_prob_orig
    del logits_ablated, forward_pass_ablated
    torch.cuda.empty_cache()

    true_token_id = input_ids[0, loss_position + 1].item()
    predicted_token_id = max_idx_orig
    true_token_str = tokenizer.decode([true_token_id])
    predicted_token_str = tokenizer.decode([predicted_token_id])
    match = (true_token_id == predicted_token_id)

    if verbose:
        # print(string)
        dropped_words = []
        for i in ablated_indices:
            tok = input_ids[0, grad_idx[int(i)]].item()
            word = tokenizer.decode([tok]).strip()
            dropped_words.append(word)
        # print(f"Words dropped: {dropped_words}")
        # print(f"True token: {true_token_str!r}")
        # print(f"Predicted token: {predicted_token_str!r}")
        # print(f"Match: {match}")

    return delta_log_prob, grad_vals, ablated_indices, tick_label_text, logits_orig_cpu, true_token_str, predicted_token_str

# %%
import json
from pathlib import Path

# Load prompts from JSON
prompts_path = Path("../data/lambada_prompts.json")
with open(prompts_path, "r", encoding="utf-8") as f:
    all_prompts_data = json.load(f)

# Handle both list-of-dicts and {prompts: [...]} formats
if isinstance(all_prompts_data, dict) and "prompts" in all_prompts_data:
    prompts_list = all_prompts_data["prompts"]
else:
    prompts_list = all_prompts_data


prompts_to_process = prompts_list[:num_prompts]

# Label: model name + scope type
label = f"{model_name_short}__{mode}_lambada_top{top_k_fraction}"
if random_ablation:
    label += "_random_drop"
results = []
for i, item in enumerate(tqdm(prompts_to_process, desc="Processing prompts")):
    # print (f"processing {i+1} of {num_prompts} prompts")
    prompt = item["text"] if isinstance(item, dict) else item

    delta_log_prob, grad_vals, ablated_indices, tick_label_text, logits_orig, true_token, predicted_token = change_in_max_log_p_with_ablation(string=prompt, top_k_fraction=top_k_fraction, verbose=True, random_ablation=random_ablation)
    # Keep last successful result for visualization cells
    _last_grad_vals, _last_ablated, _last_tick = grad_vals, ablated_indices, tick_label_text
    _last_logits = logits_orig.detach().cpu() if hasattr(logits_orig, "cpu") else logits_orig
    del logits_orig
    entry = {
        "delta_log_prob": delta_log_prob,
        "prompt": prompt,
        "true_token": true_token,
        "predicted_token": predicted_token,
        "index": i,
    }
    if isinstance(item, dict):
        entry.update({k: v for k, v in item.items() if k != "prompt"})
    results.append(entry)
# Out:
# Processing prompts:   0%|          | 0/300 [00:00<?, ?it/s]
# Computing gradient_x_input Scope...
# Processing prompts:   0%|          | 1/300 [00:01<07:45,  1.56s/it]
# Computing gradient_x_input Scope...
# Processing prompts:   1%|          | 2/300 [00:03<07:56,  1.60s/it]
# Computing gradient_x_input Scope...
# Processing prompts:   1%|          | 3/300 [00:04<07:44,  1.56s/it]
# Computing gradient_x_input Scope...
# Processing prompts:   1%|▏         | 4/300 [00:06<07:31,  1.53s/it]
# Computing gradient_x_input Scope...
# Processing prompts:   2%|▏         | 5/300 [00:07<07:32,  1.53s/it]
# Computing gradient_x_input Scope...
# Processing prompts:   2%|▏         | 6/300 [00:09<07:31,  1.53s/it]
# Computing gradient_x_input Scope...
# Processing prompts:   2%|▏         | 6/300 [00:10<08:20,  1.70s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 27
#      23 for i, item in enumerate(tqdm(prompts_to_process, desc="Processing prompts")):
#      24     # print (f"processing {i+1} of {num_prompts} prompts")
#      25     prompt = item["text"] if isinstance(item, dict) else item
# ---> 27     delta_log_prob, grad_vals, ablated_indices, tick_label_text, logits_orig, true_token, predicted_token = change_in_max_log_p_with_ablation(string=prompt, top_k_fraction=top_k_fraction, verbose=True, random_ablation=random_ablation)
#      28     # Keep last successful result for visualization cells
#      29     _last_grad_vals, _last_ablated, _last_tick = grad_vals, ablated_indices, tick_label_text
#
# Cell In[25], line 100, in change_in_max_log_p_with_ablation(string, top_k_fraction, verbose, random_ablation)
#      98 if mode == 'gradient_x_input' or mode == 'IG':
#      99     with torch.no_grad():
# --> 100         token_embeds = JCBScope_utils.embedding_lookup(input_ids[0, grad_idx], embedding_layer)
#     101     grad_vals = (grads * token_embeds.to(grads.device)).norm(dim=-1).squeeze().cpu().numpy()
#     102 if grad_vals.ndim > 1:
#
# File ~/JacobianScopes/JacobianScopes/Benchmarks/../JCBScope_utils.py:14, in embedding_lookup(indices, embedding_layer)
#      11     else:
#      12         raise ValueError(f"Unsupported model architecture: {type(model)}")
# ---> 14 def embedding_lookup(indices, embedding_layer):
#      15     """
#      16     Look up embeddings at given indices. Uses F.embedding directly to avoid
#      17     Accelerate hook device mismatches when using device_map="auto".
#      18     """
#      19     w_device = embedding_layer.weight.device
#
# KeyboardInterrupt:

# %%
label
# Out:
# 'Llama-3.2-3B__gradient_x_input_lambada_top0.05'

# %%
# Save results
result_path = Path(f"../results/{label}_results.json")
result_path.parent.mkdir(parents=True, exist_ok=True)
with open(result_path, "w", encoding="utf-8") as f:
    json.dump({"label": label, "results": results}, f, indent=2, ensure_ascii=False)

print(f"Saved {len(results)} results to {result_path}")

# Restore last successful result for visualization cells
if "_last_grad_vals" in dir():
    grad_vals, ablated_indices, tick_label_text = _last_grad_vals, _last_ablated, _last_tick
    logits_orig = _last_logits
# Out:
# Saved 300 results to ../results/Llama-3.2-3B__gradient_x_input_lambada_top0.05_results.json

# %%
## Summary of delta_log_prob for each prompt
for r in results:
    d = r.get("delta_log_prob")
    d_str = f"{d:.4f}" if d is not None else "ERROR"
    true_token = r.get('true_token', '')
    pred_token = r.get('predicted_token', '')
    is_correct = (true_token == pred_token)
    correctness = "✔" if is_correct else "✘"
    print(f"[{r['index']}] delta_log_prob={d_str}  true={true_token!r} pred={pred_token!r}  -> {correctness}")
# Out:
# [0] delta_log_prob=-1.8650  true=' couple' pred=' family'  -> ✘
# [1] delta_log_prob=-8.5047  true=' snake' pred=' snake'  -> ✔
# [2] delta_log_prob=-14.1083  true='ater' pred='ater'  -> ✔
# [3] delta_log_prob=-1.3464  true=' wards' pred=' wards'  -> ✔
# [4] delta_log_prob=-0.0304  true='f' pred='f'  -> ✔
# [5] delta_log_prob=-0.4599  true=' truck' pred=' the'  -> ✘
# [6] delta_log_prob=-6.7488  true=' stones' pred=' standing'  -> ✘
# [7] delta_log_prob=-2.3825  true=' diamonds' pred=' bracelet'  -> ✘
# [8] delta_log_prob=-15.2365  true='immer' pred='immer'  -> ✔
# [9] delta_log_prob=-6.8202  true=' sled' pred=' sled'  -> ✔
# [10] delta_log_prob=-1.8179  true=' fingers' pred=' fingers'  -> ✔
# [11] delta_log_prob=-7.9566  true='raid' pred='raid'  -> ✔
# [12] delta_log_prob=-10.0341  true=' pig' pred=' pig'  -> ✔
# [13] delta_log_prob=-0.6785  true=' bundle' pred=' object'  -> ✘
# [14] delta_log_prob=-2.4306  true=' quick' pred=' so'  -> ✘
# [15] delta_log_prob=-0.6804  true=' terrible' pred=' indeed'  -> ✘
# [16] delta_log_prob=0.0280  true=' body' pred=' body'  -> ✔
# [17] delta_log_prob=-10.5994  true=' van' pred=' van'  -> ✔
# [18] delta_log_prob=-6.0707  true=' door' pred=' door'  -> ✔
# [19] delta_log_prob=-2.5310  true=' Festival' pred=' Festival'  -> ✔
# [20] delta_log_prob=-6.7716  true=' pyramid' pred=' pyramid'  -> ✔
# [21] delta_log_prob=-3.7951  true=' switch' pred=' switch'  -> ✔
# [22] delta_log_prob=-0.0049  true='ah' pred='ah'  -> ✔
# [23] delta_log_prob=-0.6271  true=' Ellie' pred=' the'  -> ✘
# [24] delta_log_prob=-8.2729  true=' Ruby' pred=' Ruby'  -> ✔
# [25] delta_log_prob=-11.8759  true=' Toyota' pred=' Toyota'  -> ✔
# [26] delta_log_prob=-0.0028  true='ane' pred='ane'  -> ✔
# [27] delta_log_prob=-0.3217  true=' map' pred=' map'  -> ✔
# [28] delta_log_prob=-7.9029  true=' Charlie' pred=' Charlie'  -> ✔
# [29] delta_log_prob=-9.0213  true=' maze' pred=' maze'  -> ✔
# [30] delta_log_prob=-8.2873  true=' crates' pred=' crates'  -> ✔
# [31] delta_log_prob=-5.5662  true=' message' pred=' message'  -> ✔
# [32] delta_log_prob=-12.1521  true=' Becky' pred=' Becky'  -> ✔
# [33] delta_log_prob=-0.0307  true=' dot' pred=' dot'  -> ✔
# [34] delta_log_prob=-6.2481  true=' menu' pred=' menu'  -> ✔
# [35] delta_log_prob=-7.1356  true=' shadows' pred=' shadow'  -> ✘
# [36] delta_log_prob=-4.9088  true=' dragon' pred=' dragon'  -> ✔
# [37] delta_log_prob=-9.3342  true=' Charlie' pred=' Charlie'  -> ✔
# [38] delta_log_prob=-6.5043  true=' stream' pred=' stream'  -> ✔
# [39] delta_log_prob=-6.5769  true=' chosen' pred=' chosen'  -> ✔
# [40] delta_log_prob=-0.2689  true=' Jane' pred=' Jane'  -> ✔
# [41] delta_log_prob=-1.9617  true=' generator' pred=' generator'  -> ✔
# [42] delta_log_prob=-2.3221  true=' rocks' pred=' rocks'  -> ✔
# [43] delta_log_prob=-2.3267  true=' Creator' pred=' Creator'  -> ✔
# [44] delta_log_prob=0.0903  true=' mine' pred=' mine'  -> ✔
# [45] delta_log_prob=0.0575  true=' pass' pred=' hill'  -> ✘
# [46] delta_log_prob=-1.7927  true=' tunnel' pred=' tunnel'  -> ✔
# [47] delta_log_prob=-2.9627  true=' garden' pred=' valley'  -> ✘
# [48] delta_log_prob=-3.7561  true=' ashes' pred=' ashes'  -> ✔
# [49] delta_log_prob=-9.2347  true='ewolf' pred='ewolf'  -> ✔
# [50] delta_log_prob=-8.4642  true=' positive' pred=' positive'  -> ✔
# [51] delta_log_prob=-8.5901  true=' Palace' pred=' Palace'  -> ✔
# [52] delta_log_prob=-2.2153  true=' bottles' pred=' bottles'  -> ✔
# [53] delta_log_prob=-1.3572  true=' succeed' pred=' get'  -> ✘
# [54] delta_log_prob=-7.6987  true=' purse' pred=' purse'  -> ✔
# [55] delta_log_prob=0.0669  true=' Ty' pred=' him'  -> ✘
# [56] delta_log_prob=-4.7972  true=' cooking' pred=' process'  -> ✘
# [57] delta_log_prob=0.1508  true=' broker' pred=' broker'  -> ✔
# [58] delta_log_prob=-1.7166  true=' order' pred=' selection'  -> ✘
# [59] delta_log_prob=0.2566  true=' again' pred='.'  -> ✘
# [60] delta_log_prob=-7.0474  true=' Josh' pred=' Josh'  -> ✔
# [61] delta_log_prob=-0.3439  true=' bag' pred=' bag'  -> ✔
# [62] delta_log_prob=-3.8393  true=' hers' pred=' her'  -> ✘
# [63] delta_log_prob=-7.0426  true=' grate' pred=' grate'  -> ✔
# [64] delta_log_prob=0.6982  true=' stone' pred=' stone'  -> ✔
# [65] delta_log_prob=-14.0390  true='alom' pred='alom'  -> ✔
# [66] delta_log_prob=-9.3397  true=' Quinn' pred=' Quinn'  -> ✔
# [67] delta_log_prob=-4.0516  true=' neighborhood' pred=' neighbourhood'  -> ✘
# [68] delta_log_prob=-8.4355  true=' truck' pred=' truck'  -> ✔
# [69] delta_log_prob=-2.2597  true=' current' pred=' current'  -> ✔
# [70] delta_log_prob=-1.3012  true=' building' pred=' of'  -> ✘
# [71] delta_log_prob=-0.8511  true='ths' pred='ths'  -> ✔
# [72] delta_log_prob=-0.4876  true=' inside' pred=' in'  -> ✘
# [73] delta_log_prob=0.0455  true=' Frank' pred=' Frank'  -> ✔
# [74] delta_log_prob=-7.7407  true=' Abby' pred=' Abby'  -> ✔
# [75] delta_log_prob=-6.5994  true=' zombies' pred=' zombies'  -> ✔
# [76] delta_log_prob=-0.0949  true=' Chase' pred=','  -> ✘
# [77] delta_log_prob=-6.2342  true=' cube' pred=' cube'  -> ✔
# [78] delta_log_prob=-3.0086  true=' okay' pred=' okay'  -> ✔
# [79] delta_log_prob=-0.2589  true=' student' pred=' student'  -> ✔
# [80] delta_log_prob=-0.5668  true=' wardrobe' pred=' wardrobe'  -> ✔
# [81] delta_log_prob=0.1907  true=' wheel' pred=' wheel'  -> ✔
# [82] delta_log_prob=-3.4681  true=' hotel' pred=' hotel'  -> ✔
# [83] delta_log_prob=-12.7139  true='ar' pred='ar'  -> ✔
# [84] delta_log_prob=-2.0966  true=' engines' pred=' engines'  -> ✔
# [85] delta_log_prob=-6.4011  true=' girl' pred=' girl'  -> ✔
# [86] delta_log_prob=-1.4071  true=' compartments' pred=' compartments'  -> ✔
# [87] delta_log_prob=-11.3901  true='ed' pred='ed'  -> ✔
# [88] delta_log_prob=-6.7517  true=' Brad' pred=' Brad'  -> ✔
# [89] delta_log_prob=-9.1939  true='site' pred='site'  -> ✔
# [90] delta_log_prob=-4.2894  true=' ferry' pred=' Continent'  -> ✘
# [91] delta_log_prob=-9.7094  true=' giants' pred=' giants'  -> ✔
# [92] delta_log_prob=-9.3031  true=' Director' pred=' Director'  -> ✔
# [93] delta_log_prob=-0.8786  true=' Matt' pred=' Matt'  -> ✔
# [94] delta_log_prob=-0.0095  true='ky' pred='ky'  -> ✔
# [95] delta_log_prob=-4.4960  true=' date' pred=' date'  -> ✔
# [96] delta_log_prob=-1.2172  true=' maid' pred=' couch'  -> ✘
# [97] delta_log_prob=-9.3537  true=' Fang' pred=' Fang'  -> ✔
# [98] delta_log_prob=-10.0798  true='i' pred='i'  -> ✔
# [99] delta_log_prob=-0.8695  true='abelle' pred='abelle'  -> ✔
# [100] delta_log_prob=-10.3809  true='el' pred='el'  -> ✔
# [101] delta_log_prob=-8.7876  true=' dinosaurs' pred=' dinosaurs'  -> ✔
# [102] delta_log_prob=-0.5735  true=' attorney' pred=' attorney'  -> ✔
# [103] delta_log_prob=-13.3360  true=' recorder' pred=' recorder'  -> ✔
# [104] delta_log_prob=-15.7040  true='ables' pred='ables'  -> ✔
# [105] delta_log_prob=-0.0279  true=' Bob' pred=' the'  -> ✘
# [106] delta_log_prob=0.1785  true=' army' pred=' enemy'  -> ✘
# [107] delta_log_prob=-0.7025  true=' festival' pred=' time'  -> ✘
# [108] delta_log_prob=-8.7229  true=' fishing' pred=' same'  -> ✘
# [109] delta_log_prob=-2.0819  true=' workers' pred=' staff'  -> ✘
# [110] delta_log_prob=-10.0234  true=' peace' pred=' peace'  -> ✔
# [111] delta_log_prob=-0.6130  true=' ordered' pred=' said'  -> ✘
# [112] delta_log_prob=-1.0820  true=' ahead' pred=' to'  -> ✘
# [113] delta_log_prob=-6.8934  true=' Sarah' pred=' Sarah'  -> ✔
# [114] delta_log_prob=0.2276  true=' Ethan' pred=' the'  -> ✘
# [115] delta_log_prob=-12.0561  true='bles' pred='bles'  -> ✔
# [116] delta_log_prob=-0.0194  true=' Spike' pred=' the'  -> ✘
# [117] delta_log_prob=-13.6236  true='ypsy' pred='ypsy'  -> ✔
# [118] delta_log_prob=-4.2930  true=' buggy' pred=' buggy'  -> ✔
# [119] delta_log_prob=-4.6861  true=' Community' pred=' Community'  -> ✔
# [120] delta_log_prob=-6.2778  true=' hill' pred=' hill'  -> ✔
# [121] delta_log_prob=-8.6613  true='deer' pred='deer'  -> ✔
# [122] delta_log_prob=-10.0942  true=' Cara' pred=' hypnot'  -> ✘
# [123] delta_log_prob=-0.8837  true=' Patty' pred=' Josh'  -> ✘
# [124] delta_log_prob=0.1505  true=' shotgun' pred=' window'  -> ✘
# [125] delta_log_prob=-0.6556  true=' psychic' pred=' close'  -> ✘
# [126] delta_log_prob=0.1768  true=' slips' pred=' is'  -> ✘
# [127] delta_log_prob=-6.2202  true=' maps' pred=' maps'  -> ✔
# [128] delta_log_prob=-5.8287  true=' Bob' pred=' him'  -> ✘
# [129] delta_log_prob=-6.6043  true=' wagon' pred=' wagon'  -> ✔
# [130] delta_log_prob=-2.2245  true=' animals' pred=' lion'  -> ✘
# [131] delta_log_prob=0.0595  true=' dog' pred=' dog'  -> ✔
# [132] delta_log_prob=-5.1713  true=' Mercy' pred=' him'  -> ✘
# [133] delta_log_prob=-0.3485  true=' grill' pred=' phone'  -> ✘
# [134] delta_log_prob=-0.3301  true=' Cash' pred=' Cash'  -> ✔
# [135] delta_log_prob=-0.6877  true=' driver' pred=' other'  -> ✘
# [136] delta_log_prob=-2.3391  true=' shelf' pred=' shelf'  -> ✔
# [137] delta_log_prob=-3.0072  true=' boat' pred=' boat'  -> ✔
# [138] delta_log_prob=-5.6123  true='ara' pred='ara'  -> ✔
# [139] delta_log_prob=-7.1537  true=' carriage' pred=' carriage'  -> ✔
# [140] delta_log_prob=-7.0749  true=' kissing' pred=' kissing'  -> ✔
# [141] delta_log_prob=-0.0248  true=' tragedy' pred=' tragedy'  -> ✔
# [142] delta_log_prob=-0.5231  true='elle' pred='elle'  -> ✔
# [143] delta_log_prob=-9.2111  true='n' pred='n'  -> ✔
# [144] delta_log_prob=-7.9052  true=' Charlie' pred=' they'  -> ✘
# [145] delta_log_prob=-6.1743  true=' Lilly' pred=' Lilly'  -> ✔
# [146] delta_log_prob=-5.8129  true=' sled' pred=' sled'  -> ✔
# [147] delta_log_prob=-13.0510  true='igail' pred='igail'  -> ✔
# [148] delta_log_prob=-17.0549  true='hee' pred='hee'  -> ✔
# [149] delta_log_prob=-0.6922  true=' blew' pred=' blew'  -> ✔
# [150] delta_log_prob=-8.7727  true=' Dome' pred=' Dome'  -> ✔
# [151] delta_log_prob=-2.8193  true=' pass' pred=' pass'  -> ✔
# [152] delta_log_prob=-0.1866  true=' drink' pred=' drink'  -> ✔
# [153] delta_log_prob=-9.3961  true='son' pred='son'  -> ✔
# [154] delta_log_prob=-0.7769  true=' sphere' pred=' small'  -> ✘
# [155] delta_log_prob=-4.7351  true='imir' pred='imir'  -> ✔
# [156] delta_log_prob=-4.5476  true=' sanctuary' pred=' sanctuary'  -> ✔
# [157] delta_log_prob=-8.6050  true=' Mikhail' pred=' Mikhail'  -> ✔
# [158] delta_log_prob=-6.4075  true=' Ella' pred=' Ella'  -> ✔
# [159] delta_log_prob=-2.4862  true=' brush' pred=' dark'  -> ✘
# [160] delta_log_prob=-3.3556  true=' boat' pred=' boat'  -> ✔
# [161] delta_log_prob=-2.9347  true=' JJ' pred=' Tony'  -> ✘
# [162] delta_log_prob=-2.9440  true=' canyon' pred=' canyon'  -> ✔
# [163] delta_log_prob=-6.6071  true=' warehouse' pred=' door'  -> ✘
# [164] delta_log_prob=-12.5685  true='olves' pred='olves'  -> ✔
# [165] delta_log_prob=0.1929  true=' paper' pred=' paper'  -> ✔
# [166] delta_log_prob=-9.2449  true=' pod' pred=' pod'  -> ✔
# [167] delta_log_prob=-1.0033  true=' van' pred=' van'  -> ✔
# [168] delta_log_prob=-2.1072  true=' graves' pred=' graves'  -> ✔
# [169] delta_log_prob=-0.0529  true=' crumbling' pred=','  -> ✘
# [170] delta_log_prob=-0.0319  true=' wound' pred=' wound'  -> ✔
# [171] delta_log_prob=-1.9953  true=' Eddie' pred=' Eddie'  -> ✔
# [172] delta_log_prob=-0.5401  true=' hunter' pred=' woman'  -> ✘
# [173] delta_log_prob=-1.9593  true=' speaker' pred=' speaker'  -> ✔
# [174] delta_log_prob=-1.8534  true=' firm' pred=' firm'  -> ✔
# [175] delta_log_prob=-1.9204  true=' pier' pred=' pier'  -> ✔
# [176] delta_log_prob=-7.2958  true=' Kane' pred=' Kane'  -> ✔
# [177] delta_log_prob=1.0881  true=' gym' pred=' back'  -> ✘
# [178] delta_log_prob=-9.9204  true=' scene' pred=' sight'  -> ✘
# [179] delta_log_prob=-0.7068  true=' web' pred=' web'  -> ✔
# [180] delta_log_prob=0.1228  true=' caves' pred=' present'  -> ✘
# [181] delta_log_prob=-6.1347  true=' guard' pred=' guard'  -> ✔
# [182] delta_log_prob=-4.3562  true=' garage' pred=' garage'  -> ✔
# [183] delta_log_prob=-1.2436  true=' dumpster' pred=' end'  -> ✘
# [184] delta_log_prob=-2.4624  true=' hook' pred=' metal'  -> ✘
# [185] delta_log_prob=-0.1609  true='an' pred='an'  -> ✔
# [186] delta_log_prob=-1.3444  true=' bear' pred=' bear'  -> ✔
# [187] delta_log_prob=-1.0264  true=' Jenna' pred=' Jenna'  -> ✔
# [188] delta_log_prob=0.2430  true=' Ella' pred=' the'  -> ✘
# [189] delta_log_prob=-3.4626  true=' sad' pred=' sad'  -> ✔
# [190] delta_log_prob=-7.5244  true='falls' pred='falls'  -> ✔
# [191] delta_log_prob=-1.7887  true=' date' pred=' date'  -> ✔
# [192] delta_log_prob=-2.0175  true=' whistle' pred=' see'  -> ✘
# [193] delta_log_prob=-5.3875  true=' cellar' pred=' cellar'  -> ✔
# [194] delta_log_prob=-8.6076  true='u' pred='u'  -> ✔
# [195] delta_log_prob=0.1985  true=' menu' pred=' menu'  -> ✔
# [196] delta_log_prob=-9.8740  true=' ribbon' pred=' ribbon'  -> ✔
# [197] delta_log_prob=-9.8953  true=' cookie' pred=' cookie'  -> ✔
# [198] delta_log_prob=-6.1606  true=' hollow' pred=' hollow'  -> ✔
# [199] delta_log_prob=-3.9059  true=' camera' pred=' camera'  -> ✔
# [200] delta_log_prob=-4.6683  true=' queue' pred=' queue'  -> ✔
# [201] delta_log_prob=-3.6458  true='unker' pred='unker'  -> ✔
# [202] delta_log_prob=-6.7503  true=' play' pred=' project'  -> ✘
# [203] delta_log_prob=0.0599  true=' village' pred=' village'  -> ✔
# [204] delta_log_prob=-11.0048  true=' David' pred=' David'  -> ✔
# [205] delta_log_prob=-2.1295  true=' department' pred=' world'  -> ✘
# [206] delta_log_prob=-10.1359  true=' zombies' pred=' zombies'  -> ✔
# [207] delta_log_prob=-2.7877  true='ienne' pred='ienne'  -> ✔
# [208] delta_log_prob=0.2242  true=' opening' pred=' cave'  -> ✘
# [209] delta_log_prob=0.0035  true='ley' pred='ley'  -> ✔
# [210] delta_log_prob=-7.9351  true='head' pred='head'  -> ✔
# [211] delta_log_prob=-2.2745  true=' anyway' pred=' thank'  -> ✘
# [212] delta_log_prob=-3.9378  true=' convent' pred=' convent'  -> ✔
# [213] delta_log_prob=-10.5150  true=' corner' pred=' corner'  -> ✔
# [214] delta_log_prob=0.0035  true=' vampire' pred=' vampire'  -> ✔
# [215] delta_log_prob=-6.9381  true=' altar' pred=' altar'  -> ✔
# [216] delta_log_prob=-11.0564  true=' tub' pred=' tub'  -> ✔
# [217] delta_log_prob=-9.7227  true=' ghosts' pred=' ghosts'  -> ✔
# [218] delta_log_prob=-1.0240  true='codile' pred='codile'  -> ✔
# [219] delta_log_prob=-5.1580  true=' laptop' pred=' laptop'  -> ✔
# [220] delta_log_prob=-6.2830  true=' Josh' pred=' Josh'  -> ✔
# [221] delta_log_prob=-0.3072  true=' lovers' pred=' anything'  -> ✘
# [222] delta_log_prob=-10.2718  true=' pool' pred=' water'  -> ✘
# [223] delta_log_prob=-3.8894  true=' possibility' pred=' possibility'  -> ✔
# [224] delta_log_prob=-12.2409  true=' Cube' pred=' Cube'  -> ✔
# [225] delta_log_prob=-0.0816  true=' cart' pred=' cart'  -> ✔
# [226] delta_log_prob=-8.3038  true=' water' pred=' hard'  -> ✘
# [227] delta_log_prob=-4.0308  true=' race' pred=' race'  -> ✔
# [228] delta_log_prob=-5.9778  true=' novel' pred=' story'  -> ✘
# [229] delta_log_prob=-1.7554  true=' chair' pred=' sand'  -> ✘
# [230] delta_log_prob=-0.3036  true=' blush' pred=' can'  -> ✘
# [231] delta_log_prob=-3.8791  true=' advertising' pred=' advertising'  -> ✔
# [232] delta_log_prob=-11.6905  true='fire' pred='fire'  -> ✔
# [233] delta_log_prob=-0.0265  true=' horses' pred=' poor'  -> ✘
# [234] delta_log_prob=-0.0584  true='aden' pred='aden'  -> ✔
# [235] delta_log_prob=-5.1901  true='o' pred='o'  -> ✔
# [236] delta_log_prob=-5.6112  true=' email' pred=' email'  -> ✔
# [237] delta_log_prob=-7.0894  true=' customers' pred=' customers'  -> ✔
# [238] delta_log_prob=-15.1439  true='roach' pred='roach'  -> ✔
# [239] delta_log_prob=-0.3298  true=' well' pred=' well'  -> ✔
# [240] delta_log_prob=-12.4493  true='ighthouse' pred='ighthouse'  -> ✔
# [241] delta_log_prob=-5.2618  true=' Will' pred=' Will'  -> ✔
# [242] delta_log_prob=-12.4455  true=' money' pred=' notes'  -> ✘
# [243] delta_log_prob=-14.3614  true='inters' pred='inters'  -> ✔
# [244] delta_log_prob=0.6138  true=' thoughts' pred=' conversation'  -> ✘
# [245] delta_log_prob=-9.7645  true=' candle' pred=' candle'  -> ✔
# [246] delta_log_prob=-0.1235  true=' Josh' pred=' Josh'  -> ✔
# [247] delta_log_prob=-4.7612  true=' board' pred=' board'  -> ✔
# [248] delta_log_prob=-1.5155  true='ens' pred='ens'  -> ✔
# [249] delta_log_prob=-4.0514  true=' Roku' pred=' her'  -> ✘
# [250] delta_log_prob=0.3602  true=' sound' pred=' this'  -> ✘
# [251] delta_log_prob=-0.0611  true=' palace' pred=' palace'  -> ✔
# [252] delta_log_prob=-14.6753  true=' Jay' pred=' Jay'  -> ✔
# [253] delta_log_prob=-7.5225  true=' Hercules' pred=' Hercules'  -> ✔
# [254] delta_log_prob=-11.4041  true=' railing' pred=' railing'  -> ✔
# [255] delta_log_prob=-10.4614  true='ik' pred='ik'  -> ✔
# [256] delta_log_prob=-1.9885  true=' sleeve' pred=' fabric'  -> ✘
# [257] delta_log_prob=-15.1027  true='iko' pred='iko'  -> ✔
# [258] delta_log_prob=-9.0604  true=' crater' pred=' crater'  -> ✔
# [259] delta_log_prob=-0.0672  true=' pages' pred=' pages'  -> ✔
# [260] delta_log_prob=-3.3340  true=' ranch' pred=' ranch'  -> ✔
# [261] delta_log_prob=-1.2965  true=' bushes' pred=' bushes'  -> ✔
# [262] delta_log_prob=-5.4681  true=' yacht' pred=' yacht'  -> ✔
# [263] delta_log_prob=-0.3074  true=' scissors' pred=' the'  -> ✘
# [264] delta_log_prob=-0.6003  true=' frame' pred=' picture'  -> ✘
# [265] delta_log_prob=-0.9043  true=' coffin' pred=' coffin'  -> ✔
# [266] delta_log_prob=-7.5963  true=' Dawson' pred=' Dawson'  -> ✔
# [267] delta_log_prob=-8.4521  true=' Pip' pred=' Pip'  -> ✔
# [268] delta_log_prob=-7.7841  true=' glass' pred=' glass'  -> ✔
# [269] delta_log_prob=-11.0837  true='bo' pred='bo'  -> ✔
# [270] delta_log_prob=-7.6934  true=' boring' pred=' normal'  -> ✘
# [271] delta_log_prob=0.1927  true=' Willow' pred=' her'  -> ✘
# [272] delta_log_prob=-6.5646  true=' horses' pred=' horses'  -> ✔
# [273] delta_log_prob=-0.5793  true='ace' pred='ace'  -> ✔
# [274] delta_log_prob=-3.0816  true=' locals' pred=' local'  -> ✘
# [275] delta_log_prob=0.3664  true=' sister' pred=' sister'  -> ✔
# [276] delta_log_prob=0.4900  true=' tears' pred=' a'  -> ✘
# [277] delta_log_prob=-0.5994  true=' spider' pred=' spider'  -> ✔
# [278] delta_log_prob=-3.5357  true=' pew' pred=' pew'  -> ✔
# [279] delta_log_prob=-6.9589  true='ie' pred='ie'  -> ✔
# [280] delta_log_prob=-1.8684  true=' fist' pred=' fist'  -> ✔
# [281] delta_log_prob=-5.8146  true=' crate' pred=' of'  -> ✘
# [282] delta_log_prob=-1.5710  true=' bike' pred=' bike'  -> ✔
# [283] delta_log_prob=-4.3271  true='ika' pred='ika'  -> ✔
# [284] delta_log_prob=-6.4311  true=' warrant' pred=' warrant'  -> ✔
# [285] delta_log_prob=0.0142  true=' Ireland' pred=' Ireland'  -> ✔
# [286] delta_log_prob=-6.8796  true=' King' pred=' King'  -> ✔
# [287] delta_log_prob=-10.5908  true=' Lia' pred=' Lia'  -> ✔
# [288] delta_log_prob=-5.4551  true=' cafe' pred=' cafe'  -> ✔
# [289] delta_log_prob=-0.9185  true=' minors' pred=' minors'  -> ✔
# [290] delta_log_prob=-2.6751  true=' trophies' pred=' trophies'  -> ✔
# [291] delta_log_prob=-0.1487  true=' stones' pred=' stones'  -> ✔
# [292] delta_log_prob=-4.7157  true=' rest' pred=' rest'  -> ✔
# [293] delta_log_prob=0.2092  true=' kids' pred=' people'  -> ✘
# [294] delta_log_prob=-0.0326  true='s' pred='s'  -> ✔
# [295] delta_log_prob=-1.9405  true=' ramp' pred=' ground'  -> ✘
# [296] delta_log_prob=-2.8655  true=' seat' pred=' seat'  -> ✔
# [297] delta_log_prob=-4.0684  true=' impressed' pred=' impressed'  -> ✔
# [298] delta_log_prob=-1.5685  true=' Meghan' pred=' her'  -> ✘
# [299] delta_log_prob=-6.4989  true=' Mark' pred=' Mark'  -> ✔

# %%
# Report correct prediction rate
num_correct = sum(1 for r in results if r.get('true_token', '') == r.get('predicted_token', ''))
total = len(results)
accuracy = num_correct / total if total > 0 else 0.0
print(f"\nCorrect prediction rate: {num_correct}/{total} = {accuracy:.2%}")

# Report average ablation impact (mean |delta_log_prob|) and its variance
deltas = [r["delta_log_prob"] for r in results if r.get("delta_log_prob") is not None]
avg_delta = sum(deltas) / len(deltas) if deltas else float("nan")
variance_delta = (
    sum((x - avg_delta) ** 2 for x in deltas) / len(deltas) if deltas else float("nan")
)
print(f"Average ablation impact (mean |delta_log_prob|): {avg_delta:.4f}")
print(f"Variance of ablation impact (|delta_log_prob|): {variance_delta:.6f}")
# Calculate standard error of the mean (SEM) for |delta_log_prob|
import math

if deltas and len(deltas) > 1:
    std_delta = math.sqrt(variance_delta)
    sem_delta = std_delta / math.sqrt(len(deltas))
else:
    sem_delta = float("nan")

print(f"Standard error of the mean (SEM) for |delta_log_prob|: {sem_delta:.6f}")

# Save variance, average, accuracy, and total to master_results.json (label as key)
master_path = Path("../results/master_results.json")
master_path.parent.mkdir(parents=True, exist_ok=True)
master = {}
if master_path.exists():
    with open(master_path, "r", encoding="utf-8") as f:
        master = json.load(f)
entry = {
    "avg_delta": avg_delta if deltas and not np.isnan(avg_delta) else None,
    "variance_delta": variance_delta if deltas and not np.isnan(variance_delta) else None,
    "sem_delta": sem_delta,
    "accuracy": accuracy,
    "num_correct": num_correct,
    "total": total,
    
}
master[label] = entry
with open(master_path, "w", encoding="utf-8") as f:
    json.dump(master, f, indent=2)
print(f"\nSaved to {master_path} (label={label})")
# Out:
# Correct prediction rate: 218/300 = 72.67%
# Average ablation impact (mean |delta_log_prob|): -4.6044
# Variance of ablation impact (|delta_log_prob|): 17.710232
# Standard error of the mean (SEM) for |delta_log_prob|: 0.242969
#
# Saved to ../results/master_results.json (label=Llama-3.2-3B__gradient_x_input_lambada_top0.05)

# %% [markdown]
# ### Visualize prediction

# %%
import torch
k = 5
logit_vector = logits_orig[-2].detach()             

# Compute softmax probabilities
probs = torch.softmax(logit_vector, dim=-1)

# Get top k probabilities and their indices
top_probs, top_indices = torch.topk(probs, k)
top_tokens = [tokenizer.decode([idx]) for idx in top_indices]

import matplotlib.pyplot as plt

plt.figure(figsize=(6,1.5), dpi=100)
bars = plt.bar(range(k), top_probs.cpu().numpy(), tick_label=top_tokens, color='red')
plt.xticks(rotation=90, fontweight='bold', fontsize=18)
# plt.xlabel('Token',rotation=180, fontweight='bold', fontsize=12)
plt.ylabel('Probability', fontweight='bold', fontsize=16,rotation=90)
plt.yticks(rotation=90, fontweight='bold', fontsize=12)
plt.gca().yaxis.set_major_locator(plt.MaxNLocator(nbins=2))  # increase number of ticks

# plt.title(f'Top {k} Tokens in Softmax of Logits')
plt.show()

# %%
# Assign colors: gray for top tokens, blue otherwise
bar_colors = []
for i in range(len(grad_vals)):
    if i in ablated_indices:
        bar_colors.append('black')
    else:
        bar_colors.append('gray')

fig, ax = plt.subplots(figsize=(max(10, len(tick_label_text) * 0.5), 4))
ax.bar(range(len(tick_label_text)), grad_vals, color=bar_colors, edgecolor='gray', linewidth=0.5)
ax.set_xticks(range(len(tick_label_text)))
ax.set_xticklabels([t if t.strip() else '·' for t in tick_label_text], rotation=45, ha='right')
ax.set_xlabel('Token')
ax.set_ylabel('Influence')
ax.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5, alpha=0.7)

legend_patches = [
    plt.matplotlib.patches.Patch(color='black', label=f'ablated tokens'),
    plt.matplotlib.patches.Patch(color='gray', label='Other tokens')
]
ax.legend(handles=legend_patches, loc='best')

plt.tight_layout()
plt.show()
